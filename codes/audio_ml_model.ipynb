# %%
from pydub import AudioSegment
import os
import glob
f=os.path.join(r'D:\carnatic\2_Violin\wav','segment')
print(f)
# Out:
# D:\carnatic\2_Violin\wav\segment

# %%
#mp3 to wav
 
import os
import glob
import pydub
mp3_files=glob.glob("E:/carnatic/2_Violin/117/*.mp3")
print(mp3_files)
for mp3_file in mp3_files:
    wav_file=os.path.splitext(mp3_file)[0]+'.wav'
    sound=pydub.AudioSegment.from_mp3(mp3_file)
    sound.export(wav_file,format="wav")
    #os.remove(mp3_file)
print("conversion complete")
 
#wav_files=glob.glob("./*.wav")
#print(wav_files)
# Out:
# ['E:/carnatic/2_Violin/117\\Kadri Gopalnath - Brahmam Okkate Para.mp3', 'E:/carnatic/2_Violin/117\\Kadri Gopalnath - Gnana Vinayakane.mp3', 'E:/carnatic/2_Violin/117\\Kadri Gopalnath - Gnanamosagarada.mp3', 'E:/carnatic/2_Violin/117\\Kadri Gopalnath - Kamalaapta Kula.mp3']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c4d4f63f48cd> in <module>
#       9     wav_file=os.path.splitext(mp3_file)[0]+'.wav'
#      10     sound=pydub.AudioSegment.from_mp3(mp3_file)
# ---> 11     sound.export(wav_file,format="wav")
#      12     #os.remove(mp3_file)
#      13 print("conversion complete")
#
# ~\anaconda3\lib\site-packages\pydub\audio_segment.py in export(self, out_f, format, codec, bitrate, parameters, tags, id3v2_version, cover)
#     835         # a float in python 2 doesn't throw an exception
#     836         wave_data.setnframes(int(self.frame_count()))
# ...

# %%
#segmentation

#import numpy as np
#import IPython.display as ipd
import glob
from pydub import AudioSegment
import os
source=r"C:\Users\admin\Downloads\New folder (3)"
lst=glob.glob(source)
print(lst)
for filename in os.listdir(source):
    songname = f'C:\\Users\\admin\\Downloads\\New folder (3)\\{filename}'
    audio = AudioSegment.from_wav(songname) 
    n = len(audio)
    interval = 3 * 1000
    overlap = 0
    start = 0
    end = 0
    flag = 0
    counter=1
    for i in range(0,  n, interval): #2 * n
        if i == 0:
            start = 0
            end = interval  
        else: 
            start = end
            end = start + interval 
        if end >= n: 
            end = n 
            flag = 1
        chunk = audio[start:end] 
        os.makedirs(os.path.join(r'','segment'),exist_ok=True)
        file = songname+str(counter)+'.wav'
        chunk.export(file, format ="wav") 
        print("Processing chunk "+str(counter)+". Start = "+str(start)+" end = "+str(end))
        counter = counter + 1
# Out:
# ['C:\\Users\\admin\\Downloads\\New folder (3)']
# Processing chunk 1. Start = 0 end = 3000
# Processing chunk 2. Start = 3000 end = 6000
# Processing chunk 3. Start = 6000 end = 9000
# Processing chunk 4. Start = 9000 end = 12000
# Processing chunk 5. Start = 12000 end = 15000
# Processing chunk 6. Start = 15000 end = 18000
# Processing chunk 7. Start = 18000 end = 21000
# Processing chunk 8. Start = 21000 end = 24000
# Processing chunk 9. Start = 24000 end = 27000
# Processing chunk 10. Start = 27000 end = 30000
# Processing chunk 11. Start = 30000 end = 33000
# Processing chunk 12. Start = 33000 end = 36000
# Processing chunk 13. Start = 36000 end = 39000
# Processing chunk 14. Start = 39000 end = 42000
# Processing chunk 15. Start = 42000 end = 45000
# Processing chunk 16. Start = 45000 end = 48000
# Processing chunk 17. Start = 48000 end = 51000
# Processing chunk 18. Start = 51000 end = 54000
# Processing chunk 19. Start = 54000 end = 57000
# ...

# %%
#to generate csv file 
import csv
import librosa
import numpy as np
import os
header = 'filename chroma_cens chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate Instrument Tone Raaga'
for i in range(1, 21):
    header += f' mfcc{i}'

header = header.split()

file = open('sarangi_test.csv', 'w+', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)
i=0
for filename in os.listdir(r"C:\Users\admin\Downloads\New folder (3)"):    # here give the path where all your segmented audio files are saved
    i=i+1
    print(filename)
    songname = f'C:\\Users\\admin\\Downloads\\New folder (3)\\{filename}'
    y, sr = librosa.load(songname, mono=True, duration=30)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    chroma_cens=chromagram = librosa.feature.chroma_cens(y=y,sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    print(i)
    to_append = f'{filename} &{np.mean(chroma_cens)}&{np.mean(chroma_stft)}& {np.mean(rmse)}& {np.mean(spec_cent)}& {np.mean(spec_bw)}& {np.mean(rolloff)}& {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f'& {np.mean(e)}'
    file = open('sarangi_test.csv', 'a', newline='')
    to_append=to_append + '& sarangi'
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split("&"))
# Out:
# sarangi_test.wav1.wav
# 1
# sarangi_test.wav10.wav
# 2
# sarangi_test.wav11.wav
# 3
# sarangi_test.wav12.wav
# 4
# sarangi_test.wav13.wav
# 5
# sarangi_test.wav14.wav
# 6
# sarangi_test.wav15.wav
# 7
# sarangi_test.wav16.wav
# 8
# sarangi_test.wav17.wav
# 9
# sarangi_test.wav18.wav
# 10
# sarangi_test.wav19.wav
# 11
# sarangi_test.wav2.wav
# 12
# sarangi_test.wav20.wav
# 13
# sarangi_test.wav21.wav
# 14
# sarangi_test.wav22.wav
# 15
# sarangi_test.wav23.wav
# 16
# sarangi_test.wav24.wav
# 17
# sarangi_test.wav25.wav
# 18
# sarangi_test.wav26.wav
# 19
# sarangi_test.wav27.wav
# 20
# sarangi_test.wav28.wav
# 21
# sarangi_test.wav29.wav
# 22
# sarangi_test.wav3.wav
# 23
# sarangi_test.wav30.wav
# 24
# sarangi_test.wav31.wav
# 25
# sarangi_test.wav32.wav
# 26
# sarangi_test.wav33.wav
# 27
# sarangi_test.wav34.wav
# 28
# sarangi_test.wav35.wav
# 29
# sarangi_test.wav36.wav
# 30
# sarangi_test.wav37.wav
# 31
# sarangi_test.wav38.wav
# 32
# sarangi_test.wav39.wav
# 33
# ...

# %%
#to generate csv file 
import csv
import librosa
import numpy as np
import os
header = 'filename chroma_cens chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, 21):
    header += f' mfcc{i}'
header=header+' '+'Class'
header = header.split()

file = open('B.csv', 'w+', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)
i=0
for filename in os.listdir(r"E:\new hindustani\New folder\B\segment"):    # here give the path where all your segmented audio files are saved
    i=i+1
    print(filename)
    
    songname = f'E:\\new hindustani\\New folder\\B\\segment\\{filename}'
    y, sr = librosa.load(songname, mono=True, duration=30)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    chroma_cens=chromagram = librosa.feature.chroma_cens(y=y,sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    print(i)
    to_append = f'{filename} &{np.mean(chroma_cens)}&{np.mean(chroma_stft)}& {np.mean(rmse)}& {np.mean(spec_cent)}& {np.mean(spec_bw)}& {np.mean(rolloff)}& {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f'& {np.mean(e)}'
    file = open('B.csv', 'a', newline='')
    to_append=to_append + '& B'
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split("&"))
# Out:
# Ali Akbar Khan - Raga - Darbari Todi (1988)1.wav
# 1
# Ali Akbar Khan - Raga - Darbari Todi (1988)10.wav
# 2
# Ali Akbar Khan - Raga - Darbari Todi (1988)11.wav
# 3
# Ali Akbar Khan - Raga - Darbari Todi (1988)12.wav
# 4
# Ali Akbar Khan - Raga - Darbari Todi (1988)13.wav
# 5
# Ali Akbar Khan - Raga - Darbari Todi (1988)14.wav
# 6
# Ali Akbar Khan - Raga - Darbari Todi (1988)15.wav
# 7
# Ali Akbar Khan - Raga - Darbari Todi (1988)16.wav
# 8
# Ali Akbar Khan - Raga - Darbari Todi (1988)17.wav
# 9
# Ali Akbar Khan - Raga - Darbari Todi (1988)18.wav
# 10
# Ali Akbar Khan - Raga - Darbari Todi (1988)19.wav
# 11
# Ali Akbar Khan - Raga - Darbari Todi (1988)2.wav
# 12
# Ali Akbar Khan - Raga - Darbari Todi (1988)20.wav
# 13
# Ali Akbar Khan - Raga - Darbari Todi (1988)21.wav
# 14
# Ali Akbar Khan - Raga - Darbari Todi (1988)22.wav
# 15
# Ali Akbar Khan - Raga - Darbari Todi (1988)23.wav
# 16
# Ali Akbar Khan - Raga - Darbari Todi (1988)24.wav
# 17
# ...

# %%
from os import path
import os
from pydub import AudioSegment
a=['flute_test','saxophone_test']
b=r"C:\Users\admin\Downloads/"
for i in a:
    src = b+ i +".mp3"
    dst = b+i+".wav"
    sound = AudioSegment.from_mp3(src)
    sound.export(dst, format="wav")

# %%
from os import path
import os
from pydub import AudioSegment


for f in os.listdir(r'E:\new hindustani\Music_Notes/'):
    #print(f)
    try:
        b=r'E:\new hindustani\Music_Notes/'+f+'/'
        print(b)
        for i in os.listdir(b):
            print(i)
            src = b+ i
            g=i.strip('.mp3')
            #print(a)
            dst = b+g+".wav"
            print(dst)
            sound = AudioSegment.from_mp3(src)
            sound.export(dst, format="wav")
    except FileNotFoundError:
        pass
# Out:
# E:\new hindustani\Music_Notes/New folder/
# A#.mp3
# E:\new hindustani\Music_Notes/New folder/A#.wav
# A.mp3
# E:\new hindustani\Music_Notes/New folder/A.wav
# B.mp3
# E:\new hindustani\Music_Notes/New folder/B.wav
# B_1.mp3
# E:\new hindustani\Music_Notes/New folder/B_1.wav
# C#.mp3
# E:\new hindustani\Music_Notes/New folder/C#.wav
# C#_1.mp3
# E:\new hindustani\Music_Notes/New folder/C#_1.wav
# C.mp3
# E:\new hindustani\Music_Notes/New folder/C.wav
# C_1.mp3
# E:\new hindustani\Music_Notes/New folder/C_1.wav
# D#.mp3
# E:\new hindustani\Music_Notes/New folder/D#.wav
# D#_1.mp3
# E:\new hindustani\Music_Notes/New folder/D#_1.wav
# D_!.mp3
# E:\new hindustani\Music_Notes/New folder/D_!.wav
# E.mp3
# E:\new hindustani\Music_Notes/New folder/E.wav
# F#.mp3
# E:\new hindustani\Music_Notes/New folder/F#.wav
# F#_1.mp3
# E:\new hindustani\Music_Notes/New folder/F#_1.wav
# F.mp3
# E:\new hindustani\Music_Notes/New folder/F.wav
# F_1.mp3
# E:\new hindustani\Music_Notes/New folder/F_1.wav
# ...

# %%
#segmentation

#import numpy as np
#import IPython.display as ipd
import glob
from pydub import AudioSegment
import os

lst=glob.glob(source)
#print(lst)

for filename in os.listdir(r"E:\new hindustani\Music_Notes"):
    source=r"E:\new hindustani\Music_Notes"
    source=source + '/'+filename
    for i in os.listdir(source):
        if (i!='segment'):
            #print(i)

            songname=source+'/'+i
            print('a--->',songname)
            c=''
            c=source+'/'+'segment/'
            #print(i)
            a=i.strip('.wav')
            print(i)
            print(type(a))
            audio = AudioSegment.from_wav(songname) 
            n = len(audio)
            interval = 3 * 1000
            overlap = 0
            start = 0
            end = 0
            flag = 0
            counter=1
            for i in range(0,  n, interval): #2 * n
                if i == 0:
                    start = 0
                    end = interval  
                else: 
                    start = end
                    end = start + interval 
                if end >= n: 
                    end = n 
                    flag = 1
                os.makedirs(os.path.join(source,'segment'),exist_ok=True)
                chunk = audio[start:end] 
                file = c+a+str(counter)+'.wav'
                chunk.export(file, format ="wav") 
                print("Processing chunk "+str(counter)+". Start = "+str(start)+" end = "+str(end))
                counter = counter + 1
# Out:
# a---> E:\new hindustani\Music_Notes/New folder/A#.wav
# A#.wav
# <class 'str'>
# Processing chunk 1. Start = 0 end = 30000
# Processing chunk 2. Start = 30000 end = 60000
# Processing chunk 3. Start = 60000 end = 90000
# Processing chunk 4. Start = 90000 end = 120000
# Processing chunk 5. Start = 120000 end = 150000
# Processing chunk 6. Start = 150000 end = 180000
# Processing chunk 7. Start = 180000 end = 210000
# Processing chunk 8. Start = 210000 end = 240000
# Processing chunk 9. Start = 240000 end = 270000
# Processing chunk 10. Start = 270000 end = 300000
# Processing chunk 11. Start = 300000 end = 330000
# Processing chunk 12. Start = 330000 end = 360000
# Processing chunk 13. Start = 360000 end = 390000
# Processing chunk 14. Start = 390000 end = 420000
# Processing chunk 15. Start = 420000 end = 450000
# Processing chunk 16. Start = 450000 end = 480000
# Processing chunk 17. Start = 480000 end = 510000
# Processing chunk 18. Start = 510000 end = 540000
# ...

# %%
from __future__ import division
from numpy.fft import rfft
from numpy import argmax, mean, diff, log, nonzero
from scipy.signal import blackmanharris, correlate
from time import time
import sys
try:
    import soundfile as sf
except ImportError:
    from scikits.audiolab import flacread

import parabolic


def freq_from_crossings(sig, fs):
    """
    Estimate frequency by counting zero crossings
    """
    # Find all indices right before a rising-edge zero crossing
    indices = nonzero((sig[1:] >= 0) & (sig[:-1] < 0))[0]

    # Naive (Measures 1000.185 Hz for 1000 Hz, for instance)
    # crossings = indices

    # More accurate, using linear interpolation to find intersample
    # zero-crossings (Measures 1000.000129 Hz for 1000 Hz, for instance)
    crossings = [i - sig[i] / (sig[i+1] - sig[i]) for i in indices]

    # Some other interpolation based on neighboring points might be better.
    # Spline, cubic, whatever

    return fs / mean(diff(crossings))


def freq_from_fft(sig, fs):
    """
    Estimate frequency from peak of FFT
    """
    # Compute Fourier transform of windowed signal
    windowed = sig * blackmanharris(len(sig))
    f = rfft(windowed)

    # Find the peak and interpolate to get a more accurate peak
    i = argmax(abs(f))  # Just use this for less-accurate, naive version
    true_i = parabolic(log(abs(f)), i)[0]

    # Convert to equivalent frequency
    return fs * true_i / len(windowed)


def freq_from_autocorr(sig, fs):
    """
    Estimate frequency using autocorrelation
    """
    # Calculate autocorrelation and throw away the negative lags
    corr = correlate(sig, sig, mode='full')
    corr = corr[len(corr)//2:]

    # Find the first low point
    d = diff(corr)
    start = nonzero(d > 0)[0][0]

    # Find the next peak after the low point (other than 0 lag).  This bit is
    # not reliable for long signals, due to the desired peak occurring between
    # samples, and other peaks appearing higher.
    # Should use a weighting function to de-emphasize the peaks at longer lags.
    peak = argmax(corr[start:]) + start
    px, py = parabolic(corr, peak)

    return fs / px


def freq_from_HPS(sig, fs):
    """
    Estimate frequency using harmonic product spectrum (HPS)
    """
    windowed = sig * blackmanharris(len(sig))

    from pylab import subplot, plot, log, copy, show

    # harmonic product spectrum:
    c = abs(rfft(windowed))
    maxharms = 8
    subplot(maxharms, 1, 1)
    plot(log(c))
    for x in range(2, maxharms):
        a = copy(c[::x])  # Should average or maximum instead of decimating
        # max(c[::x],c[1::x],c[2::x],...)
        c = c[:len(a)]
        i = argmax(abs(c))
        true_i = parabolic(abs(c), i)[0]
        print('Pass %d: %f Hz' % (x, fs * true_i / len(windowed)))
        c *= a
        subplot(maxharms, 1, x)
        plot(log(c))
    show()


filename =  r'E:\new hindustani\A.wav'

print('Reading file "%s"\n' % filename)
try:
    signal, fs = sf.read(filename)
except NameError:
    signal, fs, enc = flacread(filename)

print('Calculating frequency from FFT:', end=' ')
start_time = time()
#print('%f Hz' % freq_from_fft(signal, fs))
print('Time elapsed: %.3f s\n' % (time() - start_time))

print('Calculating frequency from zero crossings:', end=' ')
start_time = time()
print('%f Hz' % freq_from_crossings(signal, fs))
print('Time elapsed: %.3f s\n' % (time() - start_time))

print('Calculating frequency from autocorrelation:', end=' ')
start_time = time()
#print('%f Hz' % freq_from_autocorr(signal, fs))
print('Time elapsed: %.3f s\n' % (time() - start_time))

print('Calculating frequency from harmonic product spectrum:')
start_time = time()
#freq_from_HPS(signal, fs)
print('Time elapsed: %.3f s\n' % (time() - start_time))
# Out:
# Reading file "E:\new hindustani\A.wav"
#
# Calculating frequency from FFT: Time elapsed: 0.000 s
#
# Calculating frequency from zero crossings: inf Hz
# Time elapsed: 0.018 s
#
# Calculating frequency from autocorrelation: Time elapsed: 0.000 s
#
# Calculating frequency from harmonic product spectrum:
# Time elapsed: 0.000 s
# E:\software\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in double_scalars
